# %%
import numpy as np
import socket
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Install Stable Baseline3 version >= 2.0.0a5
# #### Note some SB3 versions are not compatible with Gymnasium interface.

# %%
# !pip install "stable-baselines3[extra] >= 2.0.0a5"

# %% [markdown]
# ## Run the Java Tetris Server (v0.6) using subprocess
# #### The latest server can be found on GitHub ([JavaTetris4RL](https://github.com/aiotlab-teaching/JavaTetris4RL)).

# %%
# Download v0.5 server from AIoTLab website
# !wget http://www.aiotlab.org/teaching/oop/tetris/TetrisTCPserver_v0.6.jar

# %%
import subprocess
subprocess.Popen(["java", "-Xss256k", "-Xmx2g","-jar","models/servers/TetrisTCPserver_v0.6.5.jar"])
# Out:
# <Popen: returncode: None args: ['java', '-Xss256k', '-Xmx2g', '-jar', 'model...>
# Tetris TCP server is listening at 10612
# Address already in use (Bind failed)

# %% [markdown]
# ## Create our own Tetris Test environment by inheriting gym.Env class

# %%
import gymnasium as gym
from gymnasium import spaces

# %%
class TetrisEnv(gym.Env):
    
    metadata = {"render_modes": ["human"], "render_fps": 20}
    
    '''
        The supported actions are
        0: move -1
        1: move 1
        2: rotate 0 // counter-clockwise
        3: rotate 1 // clockwise
        4: drop down
    '''
    N_DISCRETE_ACTIONS = 5
    
    IMG_HEIGHT = 100
    IMG_WIDTH = 50
    IMG_CHANNELS = 3
    

    def __init__(self, host_ip="127.0.0.1", host_port=10612):
        super().__init__()
        
        self.action_space = spaces.Discrete(self.N_DISCRETE_ACTIONS)
        # Example for using image as input (channel-first; channel-last also works):
        self.observation_space = spaces.Box(low=0, high=255,
                                            shape=(self.IMG_HEIGHT, self.IMG_WIDTH, self.IMG_CHANNELS), dtype=np.uint8)
        self.server_ip = host_ip
        self.server_port = host_port
            
        self.client_sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.client_sock.connect((self.server_ip, self.server_port))

    def step(self, action):
        if action == 0:
            self.client_sock.sendall(b"move -1\n")
        elif action == 1:
            self.client_sock.sendall(b"move 1\n")
        elif action == 2:
            self.client_sock.sendall(b"rotate 0\n")
        elif action == 3:
            self.client_sock.sendall(b"rotate 1\n")
        elif action == 4:
            self.client_sock.sendall(b"drop\n")
            
        terminated, lines, height, holes, observation = self.get_tetris_server_response(self.client_sock)
        self.observation = observation
        
        reward = 0
        if action == 4: # Drop reward
            reward += 5
            
        # Negative height reward
        if height > self.height:
            reward -= (height - self.height)*5
        
        # Positive hole reduction reward
        if holes < self.holes:
            reward += (self.holes - holes)*10
        
        if lines > self.lines_removed:
            reward = reward + (lines - self.lines_removed)*1000
            self.lines_removed = lines
            
        self.holes = holes
        self.height = height
        self.lifetime += 1
        truncated = False
        info = {'removed_lines':self.lines_removed, 'lifetime':self.lifetime}
        return (observation, reward, terminated, truncated, info)

    def reset(self, seed=None, options=None):
        self.client_sock.sendall(b"start\n")
        terminated, lines, height, holes, observation = self.get_tetris_server_response(self.client_sock)
        self.observation = observation
        self.reward = 0
        self.lines_removed = 0
        self.holes = 0
        self.height = 0
        self.lifetime = 0
        info = {}
        return observation, info

    def render(self):
        ''''''
        #if self.render_mode == "console":
        #    print('Total reward ' + str(self.reward))
        '''
        if self.render_mode == "human":
            cv2.imshow("Image", self.observation)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
        '''

    def close(self):
        self.client_sock.close()
        
    def get_tetris_server_response(self, sock):
        is_game_over = (sock.recv(1) == b'\x01')
        removed_lines = int.from_bytes(sock.recv(4), 'big')
        holes = int.from_bytes(sock.recv(4), 'big')
        height = int.from_bytes(sock.recv(4), 'big')
        bumpiness = int.from_bytes(sock.recv(4), 'big')
        pillar = int.from_bytes(sock.recv(4), 'big')
        y_pos = int.from_bytes(sock.recv(4), 'big')
        contact = int.from_bytes(sock.recv(4), 'big')
        img_size = int.from_bytes(sock.recv(4), 'big')
        img_png = sock.recv(img_size)

        nparr = np.frombuffer(img_png, np.uint8)
        np_image = cv2.imdecode(nparr, -1)

        np_image = cv2.resize(np_image, (self.IMG_WIDTH, self.IMG_HEIGHT), interpolation=cv2.INTER_AREA)

        return is_game_over, removed_lines, height, holes, np_image

# %% [markdown]
# ## Use SB3 env_checker to check our environment

# %%
from stable_baselines3.common.env_checker import check_env

env = TetrisEnv()
# It will check your custom environment and output additional warnings if needed
# No response may be caused by mismatched action state definition and implementation
check_env(env)

# %% [markdown]
# ## Randomly test the environment

# %%
obs, info = env.reset()
n_steps = 20
for _ in range(n_steps):
    # Random action
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    
    env.render() # We render nothing now
    
    if terminated:
        break

# %%
# Show the final screen
# %matplotlib inline 
plt.imshow(obs)

# %%
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## Create an environment with 30 client threads

# %%
# Let's try A2C by creating 30 environments
vec_env = make_vec_env(TetrisEnv, n_envs=30)

# %% [markdown]
# ## We choose A2C with CNN policy, and train 2,000,000 steps

# %%
# Train the agent
model = PPO(
    "CnnPolicy",
    vec_env,
    learning_rate=lambda f: 2.5e-4 * f,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    ent_coef=0.01,
    vf_coef=0.5,
    clip_range=0.2,
    verbose=1,
)

model.learn(total_timesteps=8_000_000)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.8     |
# |    ep_rew_mean     | -368     |
# | time/              |          |
# |    fps             | 1740     |
# |    iterations      | 1        |
# |    time_elapsed    | 35       |
# |    total_timesteps | 61440    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 55.1          |
# |    ep_rew_mean          | -362          |
# | time/                   |               |
# |    fps                  | 1349          |
# |    iterations           | 2             |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 0.021353897   |
# |    clip_fraction        | 0.392         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.58         |
# |    explained_variance   | -0.0018713474 |
# |    learning_rate        | 0.000248      |
# |    loss                 | 403           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00332      |
# |    value_loss           | 1.24e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.2        |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 3           |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.022987189 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.37235808  |
# |    learning_rate        | 0.000246    |
# |    loss                 | 142         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00043     |
# |    value_loss           | 625         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.2        |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 4           |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.030607779 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.61977994  |
# |    learning_rate        | 0.000244    |
# |    loss                 | 263         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0077      |
# |    value_loss           | 388         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.1        |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 1196        |
# |    iterations           | 5           |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.039093353 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.7395972   |
# |    learning_rate        | 0.000242    |
# |    loss                 | 79.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0115      |
# |    value_loss           | 295         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.7        |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 6           |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.049316037 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.80518675  |
# |    learning_rate        | 0.00024     |
# |    loss                 | 63.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 229         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.2       |
# |    ep_rew_mean          | -359       |
# | time/                   |            |
# |    fps                  | 1176       |
# |    iterations           | 7          |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 430080     |
# | train/                  |            |
# |    approx_kl            | 0.05248479 |
# |    clip_fraction        | 0.449      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.7978244  |
# |    learning_rate        | 0.000238   |
# |    loss                 | 106        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0218     |
# |    value_loss           | 172        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.3        |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 1167        |
# |    iterations           | 8           |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.077487074 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.7886765   |
# |    learning_rate        | 0.000237    |
# |    loss                 | 68.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0282      |
# |    value_loss           | 182         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 88.4       |
# |    ep_rew_mean          | -356       |
# | time/                   |            |
# |    fps                  | 1159       |
# |    iterations           | 9          |
# |    time_elapsed         | 476        |
# |    total_timesteps      | 552960     |
# | train/                  |            |
# |    approx_kl            | 0.13463031 |
# |    clip_fraction        | 0.49       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.7653258  |
# |    learning_rate        | 0.000235   |
# |    loss                 | 62.5       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0384     |
# |    value_loss           | 144        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 91.1       |
# |    ep_rew_mean          | -382       |
# | time/                   |            |
# |    fps                  | 1156       |
# |    iterations           | 10         |
# |    time_elapsed         | 531        |
# |    total_timesteps      | 614400     |
# | train/                  |            |
# |    approx_kl            | 0.12555207 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.74711573 |
# |    learning_rate        | 0.000233   |
# |    loss                 | 125        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.0302     |
# |    value_loss           | 218        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 93.9       |
# |    ep_rew_mean          | -394       |
# | time/                   |            |
# |    fps                  | 1153       |
# |    iterations           | 11         |
# |    time_elapsed         | 585        |
# |    total_timesteps      | 675840     |
# | train/                  |            |
# |    approx_kl            | 0.1351686  |
# |    clip_fraction        | 0.336      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.714     |
# |    explained_variance   | 0.69631064 |
# |    learning_rate        | 0.000231   |
# |    loss                 | 116        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0204     |
# |    value_loss           | 303        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.3       |
# |    ep_rew_mean          | -349       |
# | time/                   |            |
# |    fps                  | 1151       |
# |    iterations           | 12         |
# |    time_elapsed         | 640        |
# |    total_timesteps      | 737280     |
# | train/                  |            |
# |    approx_kl            | 0.06971334 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | 0.7107898  |
# |    learning_rate        | 0.000229   |
# |    loss                 | 80.6       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.000523  |
# |    value_loss           | 315        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | -388       |
# | time/                   |            |
# |    fps                  | 1148       |
# |    iterations           | 13         |
# |    time_elapsed         | 695        |
# |    total_timesteps      | 798720     |
# | train/                  |            |
# |    approx_kl            | 0.54095453 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.633     |
# |    explained_variance   | 0.7420951  |
# |    learning_rate        | 0.000227   |
# |    loss                 | 81.7       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0575     |
# |    value_loss           | 231        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.9       |
# |    ep_rew_mean          | -390       |
# | time/                   |            |
# |    fps                  | 1147       |
# |    iterations           | 14         |
# |    time_elapsed         | 749        |
# |    total_timesteps      | 860160     |
# | train/                  |            |
# |    approx_kl            | 0.04781013 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.514     |
# |    explained_variance   | 0.78621835 |
# |    learning_rate        | 0.000225   |
# |    loss                 | 125        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0139     |
# |    value_loss           | 208        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 15          |
# |    time_elapsed         | 804         |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.029662479 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.77400196  |
# |    learning_rate        | 0.000223    |
# |    loss                 | 68.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 234         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72         |
# |    ep_rew_mean          | -340       |
# | time/                   |            |
# |    fps                  | 1142       |
# |    iterations           | 16         |
# |    time_elapsed         | 860        |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.06563505 |
# |    clip_fraction        | 0.342      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.656     |
# |    explained_variance   | 0.7737415  |
# |    learning_rate        | 0.000221   |
# |    loss                 | 133        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.00544    |
# |    value_loss           | 229        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.9       |
# |    ep_rew_mean          | -284       |
# | time/                   |            |
# |    fps                  | 1142       |
# |    iterations           | 17         |
# |    time_elapsed         | 914        |
# |    total_timesteps      | 1044480    |
# | train/                  |            |
# |    approx_kl            | 0.11496641 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.504     |
# |    explained_variance   | 0.8341961  |
# |    learning_rate        | 0.000219   |
# |    loss                 | 104        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0431     |
# |    value_loss           | 172        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.3       |
# |    ep_rew_mean          | -279       |
# | time/                   |            |
# |    fps                  | 1138       |
# |    iterations           | 18         |
# |    time_elapsed         | 971        |
# |    total_timesteps      | 1105920    |
# | train/                  |            |
# |    approx_kl            | 0.06769924 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.339     |
# |    explained_variance   | 0.85717535 |
# |    learning_rate        | 0.000217   |
# |    loss                 | 38.1       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.0235     |
# |    value_loss           | 98.9       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 81.5      |
# |    ep_rew_mean          | -254      |
# | time/                   |           |
# |    fps                  | 1134      |
# |    iterations           | 19        |
# |    time_elapsed         | 1028      |
# |    total_timesteps      | 1167360   |
# | train/                  |           |
# |    approx_kl            | 1.4886378 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.174    |
# |    explained_variance   | 0.8707248 |
# |    learning_rate        | 0.000215  |
# |    loss                 | 15.7      |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.0327    |
# |    value_loss           | 73.8      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 114        |
# |    ep_rew_mean          | -375       |
# | time/                   |            |
# |    fps                  | 1134       |
# |    iterations           | 20         |
# |    time_elapsed         | 1083       |
# |    total_timesteps      | 1228800    |
# | train/                  |            |
# |    approx_kl            | 0.1407725  |
# |    clip_fraction        | 0.0876     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.142     |
# |    explained_variance   | 0.86801994 |
# |    learning_rate        | 0.000214   |
# |    loss                 | 21.3       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00224   |
# |    value_loss           | 81.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 117        |
# |    ep_rew_mean          | -398       |
# | time/                   |            |
# |    fps                  | 1132       |
# |    iterations           | 21         |
# |    time_elapsed         | 1139       |
# |    total_timesteps      | 1290240    |
# | train/                  |            |
# |    approx_kl            | 0.27321574 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.282     |
# |    explained_variance   | 0.5412834  |
# |    learning_rate        | 0.000212   |
# |    loss                 | 69.1       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.0382     |
# |    value_loss           | 147        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97         |
# |    ep_rew_mean          | -312       |
# | time/                   |            |
# |    fps                  | 1131       |
# |    iterations           | 22         |
# |    time_elapsed         | 1195       |
# |    total_timesteps      | 1351680    |
# | train/                  |            |
# |    approx_kl            | 0.03617917 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.263     |
# |    explained_variance   | 0.68555737 |
# |    learning_rate        | 0.00021    |
# |    loss                 | 68.1       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0164     |
# |    value_loss           | 153        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 92.6      |
# |    ep_rew_mean          | -286      |
# | time/                   |           |
# |    fps                  | 1130      |
# |    iterations           | 23        |
# |    time_elapsed         | 1250      |
# |    total_timesteps      | 1413120   |
# | train/                  |           |
# |    approx_kl            | 0.4056736 |
# |    clip_fraction        | 0.0317    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00927  |
# |    explained_variance   | 0.6690259 |
# |    learning_rate        | 0.000208  |
# |    loss                 | 129       |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 0.00581   |
# |    value_loss           | 133       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95            |
# |    ep_rew_mean          | -285          |
# | time/                   |               |
# |    fps                  | 1128          |
# |    iterations           | 24            |
# |    time_elapsed         | 1307          |
# |    total_timesteps      | 1474560       |
# | train/                  |               |
# |    approx_kl            | -2.522332e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.62e-08     |
# |    explained_variance   | 0.814569      |
# |    learning_rate        | 0.000206      |
# |    loss                 | 27.9          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -2.31e-09     |
# |    value_loss           | 92.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.1          |
# |    ep_rew_mean          | -287          |
# | time/                   |               |
# |    fps                  | 1128          |
# |    iterations           | 25            |
# |    time_elapsed         | 1360          |
# |    total_timesteps      | 1536000       |
# | train/                  |               |
# |    approx_kl            | -9.216213e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.3e-07      |
# |    explained_variance   | 0.88790447    |
# |    learning_rate        | 0.000204      |
# |    loss                 | 54.1          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -1.31e-08     |
# |    value_loss           | 83.9          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 93.6           |
# |    ep_rew_mean          | -292           |
# | time/                   |                |
# |    fps                  | 1128           |
# |    iterations           | 26             |
# |    time_elapsed         | 1415           |
# |    total_timesteps      | 1597440        |
# | train/                  |                |
# |    approx_kl            | -1.3581787e-10 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -9.6e-07       |
# |    explained_variance   | 0.9047562      |
# |    learning_rate        | 0.000202       |
# |    loss                 | 50.1           |
# |    n_updates            | 250            |
# |    policy_gradient_loss | 9.84e-09       |
# |    value_loss           | 83.2           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.9          |
# |    ep_rew_mean          | -288          |
# | time/                   |               |
# |    fps                  | 1127          |
# |    iterations           | 27            |
# |    time_elapsed         | 1470          |
# |    total_timesteps      | 1658880       |
# | train/                  |               |
# |    approx_kl            | -6.887906e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.12e-06     |
# |    explained_variance   | 0.90275604    |
# |    learning_rate        | 0.0002        |
# |    loss                 | 40            |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 6.02e-08      |
# |    value_loss           | 79.8          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 95.5           |
# |    ep_rew_mean          | -281           |
# | time/                   |                |
# |    fps                  | 1128           |
# |    iterations           | 28             |
# |    time_elapsed         | 1524           |
# |    total_timesteps      | 1720320        |
# | train/                  |                |
# |    approx_kl            | -4.9476513e-11 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.97e-06      |
# |    explained_variance   | 0.89757055     |
# |    learning_rate        | 0.000198       |
# |    loss                 | 55.6           |
# |    n_updates            | 270            |
# |    policy_gradient_loss | 2.93e-07       |
# |    value_loss           | 82.3           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.6          |
# |    ep_rew_mean          | -288          |
# | time/                   |               |
# |    fps                  | 1129          |
# |    iterations           | 29            |
# |    time_elapsed         | 1577          |
# |    total_timesteps      | 1781760       |
# | train/                  |               |
# |    approx_kl            | -3.880511e-12 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22e-06     |
# |    explained_variance   | 0.89221114    |
# |    learning_rate        | 0.000196      |
# |    loss                 | 38            |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 8.94e-08      |
# |    value_loss           | 79.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.3         |
# |    ep_rew_mean          | -284         |
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 30           |
# |    time_elapsed         | 1631         |
# |    total_timesteps      | 1843200      |
# | train/                  |              |
# |    approx_kl            | 1.086543e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.45e-06    |
# |    explained_variance   | 0.8925193    |
# |    learning_rate        | 0.000194     |
# |    loss                 | 22.5         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 2.31e-07     |
# |    value_loss           | 83.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93           |
# |    ep_rew_mean          | -289         |
# | time/                   |              |
# |    fps                  | 1131         |
# |    iterations           | 31           |
# |    time_elapsed         | 1683         |
# |    total_timesteps      | 1904640      |
# | train/                  |              |
# |    approx_kl            | 9.846796e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.9e-06     |
# |    explained_variance   | 0.8986556    |
# |    learning_rate        | 0.000192     |
# |    loss                 | 21.1         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 9.22e-08     |
# |    value_loss           | 80.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | -358       |
# | time/                   |            |
# |    fps                  | 1130       |
# |    iterations           | 32         |
# |    time_elapsed         | 1739       |
# |    total_timesteps      | 1966080    |
# | train/                  |            |
# |    approx_kl            | 0.0199304  |
# |    clip_fraction        | 0.0446     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.108     |
# |    explained_variance   | 0.88927275 |
# |    learning_rate        | 0.00019    |
# |    loss                 | 57.9       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00707   |
# |    value_loss           | 79.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.4       |
# |    ep_rew_mean          | -251       |
# | time/                   |            |
# |    fps                  | 1131       |
# |    iterations           | 33         |
# |    time_elapsed         | 1791       |
# |    total_timesteps      | 2027520    |
# | train/                  |            |
# |    approx_kl            | 1.6537967  |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0858    |
# |    explained_variance   | 0.74722624 |
# |    learning_rate        | 0.000189   |
# |    loss                 | 27.2       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0148     |
# |    value_loss           | 118        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 95.3      |
# |    ep_rew_mean          | -280      |
# | time/                   |           |
# |    fps                  | 1131      |
# |    iterations           | 34        |
# |    time_elapsed         | 1846      |
# |    total_timesteps      | 2088960   |
# | train/                  |           |
# |    approx_kl            | 1.7263873 |
# |    clip_fraction        | 0.167     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0134   |
# |    explained_variance   | 0.772755  |
# |    learning_rate        | 0.000187  |
# |    loss                 | 67.4      |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.0818    |
# |    value_loss           | 136       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.7        |
# |    ep_rew_mean          | -254        |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 35          |
# |    time_elapsed         | 1901        |
# |    total_timesteps      | 2150400     |
# | train/                  |             |
# |    approx_kl            | 0.037158087 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0932     |
# |    explained_variance   | 0.8749748   |
# |    learning_rate        | 0.000185    |
# |    loss                 | 53.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 80          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 94.8       |
# |    ep_rew_mean          | -284       |
# | time/                   |            |
# |    fps                  | 1131       |
# |    iterations           | 36         |
# |    time_elapsed         | 1955       |
# |    total_timesteps      | 2211840    |
# | train/                  |            |
# |    approx_kl            | 0.45042074 |
# |    clip_fraction        | 0.0668     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00664   |
# |    explained_variance   | 0.83902746 |
# |    learning_rate        | 0.000183   |
# |    loss                 | 35.4       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0334     |
# |    value_loss           | 91.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71.4       |
# |    ep_rew_mean          | -244       |
# | time/                   |            |
# |    fps                  | 1131       |
# |    iterations           | 37         |
# |    time_elapsed         | 2009       |
# |    total_timesteps      | 2273280    |
# | train/                  |            |
# |    approx_kl            | 0.03683927 |
# |    clip_fraction        | 0.056      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0762    |
# |    explained_variance   | 0.88647133 |
# |    learning_rate        | 0.000181   |
# |    loss                 | 49         |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0113    |
# |    value_loss           | 76         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92.3       |
# |    ep_rew_mean          | -285       |
# | time/                   |            |
# |    fps                  | 1132       |
# |    iterations           | 38         |
# |    time_elapsed         | 2061       |
# |    total_timesteps      | 2334720    |
# | train/                  |            |
# |    approx_kl            | 0.883381   |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00301   |
# |    explained_variance   | 0.85731906 |
# |    learning_rate        | 0.000179   |
# |    loss                 | 40.1       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0454     |
# |    value_loss           | 86.9       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 69.3      |
# |    ep_rew_mean          | -252      |
# | time/                   |           |
# |    fps                  | 1132      |
# |    iterations           | 39        |
# |    time_elapsed         | 2115      |
# |    total_timesteps      | 2396160   |
# | train/                  |           |
# |    approx_kl            | 0.0528126 |
# |    clip_fraction        | 0.0884    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.118    |
# |    explained_variance   | 0.8735306 |
# |    learning_rate        | 0.000177  |
# |    loss                 | 28.4      |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0195   |
# |    value_loss           | 79.7      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 94        |
# |    ep_rew_mean          | -288      |
# | time/                   |           |
# |    fps                  | 1133      |
# |    iterations           | 40        |
# |    time_elapsed         | 2168      |
# |    total_timesteps      | 2457600   |
# | train/                  |           |
# |    approx_kl            | 0.8881865 |
# |    clip_fraction        | 0.107     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0122   |
# |    explained_variance   | 0.8641443 |
# |    learning_rate        | 0.000175  |
# |    loss                 | 40.1      |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.0396    |
# |    value_loss           | 90.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.1        |
# |    ep_rew_mean          | -261        |
# | time/                   |             |
# |    fps                  | 1133        |
# |    iterations           | 41          |
# |    time_elapsed         | 2222        |
# |    total_timesteps      | 2519040     |
# | train/                  |             |
# |    approx_kl            | 0.050666805 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.121      |
# |    explained_variance   | 0.88230604  |
# |    learning_rate        | 0.000173    |
# |    loss                 | 13.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 76.2        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 93.2      |
# |    ep_rew_mean          | -296      |
# | time/                   |           |
# |    fps                  | 1131      |
# |    iterations           | 42        |
# |    time_elapsed         | 2280      |
# |    total_timesteps      | 2580480   |
# | train/                  |           |
# |    approx_kl            | 1.2307256 |
# |    clip_fraction        | 0.103     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00446  |
# |    explained_variance   | 0.8610858 |
# |    learning_rate        | 0.000171  |
# |    loss                 | 27.8      |
# |    n_updates            | 410       |
# |    policy_gradient_loss | 0.0411    |
# |    value_loss           | 88.6      |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.9          |
# |    ep_rew_mean          | -292          |
# | time/                   |               |
# |    fps                  | 1130          |
# |    iterations           | 43            |
# |    time_elapsed         | 2336          |
# |    total_timesteps      | 2641920       |
# | train/                  |               |
# |    approx_kl            | 9.1192005e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -8.75e-07     |
# |    explained_variance   | 0.88018125    |
# |    learning_rate        | 0.000169      |
# |    loss                 | 17.3          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 2.75e-08      |
# |    value_loss           | 77.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.2         |
# |    ep_rew_mean          | -285         |
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 44           |
# |    time_elapsed         | 2390         |
# |    total_timesteps      | 2703360      |
# | train/                  |              |
# |    approx_kl            | 1.891749e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27e-06    |
# |    explained_variance   | 0.8922889    |
# |    learning_rate        | 0.000167     |
# |    loss                 | 10.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 1.14e-08     |
# |    value_loss           | 77.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.2       |
# |    ep_rew_mean          | -249       |
# | time/                   |            |
# |    fps                  | 1130       |
# |    iterations           | 45         |
# |    time_elapsed         | 2445       |
# |    total_timesteps      | 2764800    |
# | train/                  |            |
# |    approx_kl            | 0.07067356 |
# |    clip_fraction        | 0.0539     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.106     |
# |    explained_variance   | 0.8847152  |
# |    learning_rate        | 0.000166   |
# |    loss                 | 29.5       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00929   |
# |    value_loss           | 77.1       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 92.9      |
# |    ep_rew_mean          | -292      |
# | time/                   |           |
# |    fps                  | 1130      |
# |    iterations           | 46        |
# |    time_elapsed         | 2499      |
# |    total_timesteps      | 2826240   |
# | train/                  |           |
# |    approx_kl            | 2.5745022 |
# |    clip_fraction        | 0.254     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0134   |
# |    explained_variance   | 0.8187229 |
# |    learning_rate        | 0.000164  |
# |    loss                 | 90.1      |
# |    n_updates            | 450       |
# |    policy_gradient_loss | 0.0452    |
# |    value_loss           | 168       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.7          |
# |    ep_rew_mean          | -285          |
# | time/                   |               |
# |    fps                  | 1131          |
# |    iterations           | 47            |
# |    time_elapsed         | 2552          |
# |    total_timesteps      | 2887680       |
# | train/                  |               |
# |    approx_kl            | 5.2677934e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35e-06     |
# |    explained_variance   | 0.87783974    |
# |    learning_rate        | 0.000162      |
# |    loss                 | 18.6          |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -1.06e-07     |
# |    value_loss           | 77.4          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 68.4       |
# |    ep_rew_mean          | -253       |
# | time/                   |            |
# |    fps                  | 1130       |
# |    iterations           | 48         |
# |    time_elapsed         | 2609       |
# |    total_timesteps      | 2949120    |
# | train/                  |            |
# |    approx_kl            | 0.0506738  |
# |    clip_fraction        | 0.0247     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.038     |
# |    explained_variance   | 0.89052635 |
# |    learning_rate        | 0.00016    |
# |    loss                 | 28.7       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00491   |
# |    value_loss           | 78.2       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 94.8      |
# |    ep_rew_mean          | -288      |
# | time/                   |           |
# |    fps                  | 1130      |
# |    iterations           | 49        |
# |    time_elapsed         | 2663      |
# |    total_timesteps      | 3010560   |
# | train/                  |           |
# |    approx_kl            | 1.5666006 |
# |    clip_fraction        | 0.121     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00903  |
# |    explained_variance   | 0.8521782 |
# |    learning_rate        | 0.000158  |
# |    loss                 | 43.7      |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 0.0361    |
# |    value_loss           | 115       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71.7       |
# |    ep_rew_mean          | -254       |
# | time/                   |            |
# |    fps                  | 1131       |
# |    iterations           | 50         |
# |    time_elapsed         | 2716       |
# |    total_timesteps      | 3072000    |
# | train/                  |            |
# |    approx_kl            | 0.05368549 |
# |    clip_fraction        | 0.0684     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0845    |
# |    explained_variance   | 0.8888943  |
# |    learning_rate        | 0.000156   |
# |    loss                 | 27.8       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 76.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92.8       |
# |    ep_rew_mean          | -291       |
# | time/                   |            |
# |    fps                  | 1127       |
# |    iterations           | 51         |
# |    time_elapsed         | 2778       |
# |    total_timesteps      | 3133440    |
# | train/                  |            |
# |    approx_kl            | 0.50549924 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0053    |
# |    explained_variance   | 0.8719384  |
# |    learning_rate        | 0.000154   |
# |    loss                 | 65.1       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.0411     |
# |    value_loss           | 91.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.3         |
# |    ep_rew_mean          | -288         |
# | time/                   |              |
# |    fps                  | 1126         |
# |    iterations           | 52           |
# |    time_elapsed         | 2835         |
# |    total_timesteps      | 3194880      |
# | train/                  |              |
# |    approx_kl            | 0.0022629797 |
# |    clip_fraction        | 0.00446      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00489     |
# |    explained_variance   | 0.8718134    |
# |    learning_rate        | 0.000152     |
# |    loss                 | 93.7         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000425    |
# |    value_loss           | 81.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.8        |
# |    ep_rew_mean          | -256        |
# | time/                   |             |
# |    fps                  | 1127        |
# |    iterations           | 53          |
# |    time_elapsed         | 2888        |
# |    total_timesteps      | 3256320     |
# | train/                  |             |
# |    approx_kl            | 0.057383094 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0696     |
# |    explained_variance   | 0.88139075  |
# |    learning_rate        | 0.00015     |
# |    loss                 | 19.7        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 75.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 90.3      |
# |    ep_rew_mean          | -281      |
# | time/                   |           |
# |    fps                  | 1127      |
# |    iterations           | 54        |
# |    time_elapsed         | 2942      |
# |    total_timesteps      | 3317760   |
# | train/                  |           |
# |    approx_kl            | 0.6927378 |
# |    clip_fraction        | 0.141     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.015    |
# |    explained_variance   | 0.8517598 |
# |    learning_rate        | 0.000148  |
# |    loss                 | 18.4      |
# |    n_updates            | 530       |
# |    policy_gradient_loss | 0.0431    |
# |    value_loss           | 122       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.2        |
# |    ep_rew_mean          | -268        |
# | time/                   |             |
# |    fps                  | 1127        |
# |    iterations           | 55          |
# |    time_elapsed         | 2996        |
# |    total_timesteps      | 3379200     |
# | train/                  |             |
# |    approx_kl            | 0.048240878 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0742     |
# |    explained_variance   | 0.87761146  |
# |    learning_rate        | 0.000146    |
# |    loss                 | 49.4        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 76.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 93.7       |
# |    ep_rew_mean          | -284       |
# | time/                   |            |
# |    fps                  | 1128       |
# |    iterations           | 56         |
# ...
# |    value_loss           | 56.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.5        |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 86          |
# |    time_elapsed         | 4708        |
# |    total_timesteps      | 5283840     |
# | train/                  |             |
# |    approx_kl            | 0.011251783 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0243     |
# |    explained_variance   | 0.89846134  |
# |    learning_rate        | 8.68e-05    |
# |    loss                 | 20.8        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00446     |
# |    value_loss           | 55.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 87          |
# |    time_elapsed         | 4765        |
# |    total_timesteps      | 5345280     |
# | train/                  |             |
# |    approx_kl            | 0.012722059 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0223     |
# |    explained_variance   | 0.8932753   |
# |    learning_rate        | 8.49e-05    |
# |    loss                 | 14          |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.00389     |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 88          |
# |    time_elapsed         | 4819        |
# |    total_timesteps      | 5406720     |
# | train/                  |             |
# |    approx_kl            | 0.009398688 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0221     |
# |    explained_variance   | 0.891967    |
# |    learning_rate        | 8.3e-05     |
# |    loss                 | 28          |
# |    n_updates            | 870         |
# |    policy_gradient_loss | 0.00349     |
# |    value_loss           | 57.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | -249        |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 89          |
# |    time_elapsed         | 4873        |
# |    total_timesteps      | 5468160     |
# | train/                  |             |
# |    approx_kl            | 0.011172414 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0228     |
# |    explained_variance   | 0.8932625   |
# |    learning_rate        | 8.1e-05     |
# |    loss                 | 25.3        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.00375     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.3        |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 90          |
# |    time_elapsed         | 4930        |
# |    total_timesteps      | 5529600     |
# | train/                  |             |
# |    approx_kl            | 0.020987367 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.051      |
# |    explained_variance   | 0.8925957   |
# |    learning_rate        | 7.91e-05    |
# |    loss                 | 11.9        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.000664    |
# |    value_loss           | 60.4        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 81.2      |
# |    ep_rew_mean          | -242      |
# | time/                   |           |
# |    fps                  | 1121      |
# |    iterations           | 91        |
# |    time_elapsed         | 4984      |
# |    total_timesteps      | 5591040   |
# | train/                  |           |
# |    approx_kl            | 0.9519846 |
# |    clip_fraction        | 0.132     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0654   |
# |    explained_variance   | 0.5722368 |
# |    learning_rate        | 7.72e-05  |
# |    loss                 | 57.1      |
# |    n_updates            | 900       |
# |    policy_gradient_loss | 0.0455    |
# |    value_loss           | 158       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.6        |
# |    ep_rew_mean          | -242        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 92          |
# |    time_elapsed         | 5040        |
# |    total_timesteps      | 5652480     |
# | train/                  |             |
# |    approx_kl            | 0.021249745 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.031      |
# |    explained_variance   | 0.78239465  |
# |    learning_rate        | 7.53e-05    |
# |    loss                 | 22.5        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.0137      |
# |    value_loss           | 73.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.1        |
# |    ep_rew_mean          | -284        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 93          |
# |    time_elapsed         | 5095        |
# |    total_timesteps      | 5713920     |
# | train/                  |             |
# |    approx_kl            | 0.024126066 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0428     |
# |    explained_variance   | 0.8625904   |
# |    learning_rate        | 7.34e-05    |
# |    loss                 | 24.8        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00514     |
# |    value_loss           | 66          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.1       |
# |    ep_rew_mean          | -258       |
# | time/                   |            |
# |    fps                  | 1121       |
# |    iterations           | 94         |
# |    time_elapsed         | 5147       |
# |    total_timesteps      | 5775360    |
# | train/                  |            |
# |    approx_kl            | 0.10165708 |
# |    clip_fraction        | 0.0647     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0431    |
# |    explained_variance   | 0.58881176 |
# |    learning_rate        | 7.14e-05   |
# |    loss                 | 45.3       |
# |    n_updates            | 930        |
# |    policy_gradient_loss | 0.0243     |
# |    value_loss           | 159        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 80.9       |
# |    ep_rew_mean          | -238       |
# | time/                   |            |
# |    fps                  | 1121       |
# |    iterations           | 95         |
# |    time_elapsed         | 5203       |
# |    total_timesteps      | 5836800    |
# | train/                  |            |
# |    approx_kl            | 0.10603819 |
# |    clip_fraction        | 0.0356     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0242    |
# |    explained_variance   | 0.7012806  |
# |    learning_rate        | 6.95e-05   |
# |    loss                 | 29.9       |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.0136     |
# |    value_loss           | 115        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.1        |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 96          |
# |    time_elapsed         | 5261        |
# |    total_timesteps      | 5898240     |
# | train/                  |             |
# |    approx_kl            | 0.021615092 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0211     |
# |    explained_variance   | 0.79187155  |
# |    learning_rate        | 6.76e-05    |
# |    loss                 | 35.4        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00941     |
# |    value_loss           | 77.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.5        |
# |    ep_rew_mean          | -256        |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 97          |
# |    time_elapsed         | 5316        |
# |    total_timesteps      | 5959680     |
# | train/                  |             |
# |    approx_kl            | 0.017114317 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0241     |
# |    explained_variance   | 0.86013186  |
# |    learning_rate        | 6.57e-05    |
# |    loss                 | 45.5        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.00729     |
# |    value_loss           | 66          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87          |
# |    ep_rew_mean          | -259        |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 98          |
# |    time_elapsed         | 5371        |
# |    total_timesteps      | 6021120     |
# | train/                  |             |
# |    approx_kl            | 0.066082664 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0259     |
# |    explained_variance   | 0.7700043   |
# |    learning_rate        | 6.38e-05    |
# |    loss                 | 58          |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 95.5        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#       1 # Train the agent
#       2 model = PPO(
#       3     "CnnPolicy",
#       4     vec_env,
#    (...)
#      12     verbose=1,
#      13 )
# ---> 15 model.learn(total_timesteps=8_000_000)
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/envs/dlearn/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# Cell In[7], line 45, in TetrisEnv.step(self, action)
#      42 elif action == 4:
#      43     self.client_sock.sendall(b"drop\n")
# ---> 45 terminated, lines, height, holes, observation = self.get_tetris_server_response(self.client_sock)
#      46 self.observation = observation
#      48 reward = 0
#
# Cell In[7], line 106, in TetrisEnv.get_tetris_server_response(self, sock)
#     104 y_pos = int.from_bytes(sock.recv(4), 'big')
#     105 contact = int.from_bytes(sock.recv(4), 'big')
# --> 106 img_size = int.from_bytes(sock.recv(4), 'big')
#     107 img_png = sock.recv(img_size)
#     109 nparr = np.frombuffer(img_png, np.uint8)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test our model with 1000 steps and record all plays.

# %%
import os
import shutil

# Test the trained agent
# using the vecenv
obs = vec_env.reset()
test_steps = 1000

replay_folder = './replay'
if os.path.exists(replay_folder):
    shutil.rmtree(replay_folder)

n_env = obs.shape[0] # Number of environments. A2C will play all envs
ep_id = np.zeros(n_env, int)
ep_steps = np.zeros(n_env, int)
cum_reward = np.zeros(n_env)
max_reward = -1e10
max_game_id = 0
max_ep_id = 0
max_rm_lines = 0
max_lifetime = 0

for step in range(test_steps):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    
    if step % 20 == 0:
        print(f"Step {step}")
        print("Action: ", action)
        print("reward=", reward, " done=", done)
        
    for eID in range(n_env):
        cum_reward[eID] += reward[eID]
        folder = f'{replay_folder}/{eID}/{ep_id[eID]}'
        if not os.path.exists(folder):
            os.makedirs(folder)
        fname = folder + '/' + '{:06d}'.format(ep_steps[eID]) + '.png'
        cv2.imwrite(fname, obs[eID])
        #cv2.imshow("Image" + str(eID), obs[eID])
        #cv2.waitKey(10)
        ep_steps[eID] += 1
        
        if done[eID]:
            if cum_reward[eID] > max_reward:
                max_reward = cum_reward[eID]
                max_game_id = eID
                max_ep_id = ep_id[eID]
                max_rm_lines = info[eID]['removed_lines']
                max_lifetime = info[eID]['lifetime']
                
            ep_id[eID] += 1
            cum_reward[eID] = 0
            ep_steps[eID] = 0

#cv2.destroyAllWindows()

# %%
best_replay_path = replay_folder + '/' + str(max_game_id) + '/' + str(max_ep_id)

print("After playing 30 envs each for ", test_steps, " steps:")
print(" Max reward=", max_reward, " Best video: " + best_replay_path)
print(" Removed lines=", max_rm_lines, " lifetime=", max_lifetime)

# %% [markdown]
# ## Make a gif image to visualize the best play

# %%
import glob
import imageio

filenames = sorted(glob.glob(best_replay_path + '/*.png'))

images = []
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('replay.gif', images, loop=0)

# %%
from IPython.display import Image
Image(filename='/kaggle/working/replay.gif')

# %%
model.save('your_studentID_a2c_30env_2M.zip')

# %%
with open('submission.csv', 'w') as fs:
    fs.write('Id,Predicted\n')
    fs.write(f'game_score,{max_reward}\n')

# %%
# Upload your results to Kaggle
from IPython.display import FileLink
FileLink('submission.csv')
